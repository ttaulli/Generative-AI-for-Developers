# %% [markdown]
# # Blog Creator

# %%
import openai
import os

# %%
os.environ['OPENAI_API_KEY'] = ''

# %%
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def create_blog_post(topic, length=300):

    prompt = f''' 
    
    Write a blog about {topic}. 
    
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))

blog_text = create_blog_post(topic, length)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 200
# Generative AI: Shaping a New Era of Creativity
#
# Artificial intelligence has come a long way in the past few years. Though it started merely as a tool for repetitive tasks and decision making in specific areas, it has now ventured into unexplored frontiers of creativity. One of the biggest breakthroughs in AI research is the creation of "generative AI." At its core, generative AI is the branch of AI that enables a machine to create original content like images, music, and text.
#
# The beauty of generative AI lies in its ability to learn how to create new content based on existing datasets. This means that a machine can analyze millions of images, for instance, and learn the intricate patterns that make up each image, before creating an entirely new image that has never been seen before. Unlike traditional AI, where a machine can only operate within pre-defined limits, generative AI goes beyond specific constraints and creates from scratch.
#
# Generative AI can be divided into two categories:

# %%
def create_blog_post(topic, length=300):

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))

blog_text = create_blog_post(topic, length)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 200
# Generative AI is an exciting field that involves training algorithms to produce original content, such as images, music, and text. While traditional AI systems are designed to perform a specific task, generative AI can create something entirely new. This technology is increasingly being used in industries such as gaming, art, and music.
#
# One of the main advantages of generative AI is its ability to learn and adapt to new data. For example, a machine learning algorithm can be trained on a dataset of images and then generate entirely new images based on the patterns it has learned. This allows artists and designers to create unique and original content with minimal effort.
#
# Another important application of generative AI is in language processing. Natural language generation (NLG) is a branch of generative AI that can learn to write articles, summaries, and even entire books. This technology has the potential to revolutionize the way we create content, making it faster and easier than ever before.
#
# Overall, generative AI is a powerful tool that has the potential to transform industries and change the way we create and consume content. As this technology continues to improve, we can expect to see even more exciting applications in the future.

# %%
def create_blog_post(topic, length=300):

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    Create an interesting title for the blog.
    
    Use the following format for the blog:

    Title: <title of the blog>
    Blog: <the text of the blog>
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))

blog_text = create_blog_post(topic, length)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 200
# Title: Generating Infinite Creativity with Generative AI
#
# Blog: Generative AI is a powerful technology that uses machine learning techniques to create new and unique content automatically. It has become increasingly popular in recent years as it empowers businesses and individuals to produce infinite variations of content quickly and efficiently.
#
# Generative AI works by training algorithms on large amounts of data to recognize patterns and generate new content that matches the input data's style and structure. This technology can produce anything from art and music to text and videos, using a variety of techniques such as deep learning and natural language processing.
#
# One of the most interesting aspects of generative AI is that it can generate infinite variations of content that humans might take months or years to create. This makes it a valuable tool for businesses that need to produce an endless stream of creative content to keep their audiences engaged.
#
# Moreover, generative AI can help creatives break out of their creative ruts. Writers, for instance, can generate multiple plot points and storylines at a push of a button, or visual artists could instantly create countless designs and patterns to choose from. This technology's infinite possibilities provide limitless potential for creative problem-solving.
#
# In summary, generative AI brings remarkable opportunities for businesses and creatives to generate infinite content with ease. With the technology's ability to generate novel and exciting possibilities, we can only imagine how generative AI will impact the future of content creation.

# %%
def create_blog_post(topic, length=300):

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    Create an interesting title for the blog.
    
    Use the following format for the blog:

    Title: <title of the blog>
    Date: <current date>
    Blog: <the text of the blog>
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))

blog_text = create_blog_post(topic, length)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 200
# Title: The Power of Generative AI
# Date: October 11, 2021
#
# Generative AI, also known as creative AI, refers to the type of artificial intelligence system that can create and generate wholly new and unique content on its own, without human intervention. A generative AI model can be trained on a dataset and use that knowledge to create a completely new work that is similar to the data it has learned from.
#
# Generative AI has been around for a while, but recent advancements in machine learning have allowed for more sophisticated and advanced models. These models can create everything from images, sound, and text, to more complex tasks like dialogue and storytelling.
#
# One of the most significant advantages of generative AI is its ability to be creative and imaginative, going beyond the limitations of human thinking. It has the potential to revolutionize various industries like fashion, entertainment, and advertising. For instance, generative AI can be used by fashion designers to create unique designs and fabrics that humans may not have thought of before.
#
# But, much work needs to be done to ensure that generative AI can be ethical and responsible. Although it can be a powerful tool, it is essential to ensure that these models do not create problematic content that can cause harm. We need robust safety check measures to prevent offensive, discriminatory, or misleading content.
#
# In conclusion, generative AI presents an exciting opportunity that can offer creative and innovative solutions. Though it needs to be used responsibly, it is clear that this technology will play a vital role in shaping the future of many industries.

# %%
def create_blog_post(topic, length=300):

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    Create an interesting title for the blog.  Also, translate the title and blog tet
    into HTML.
    
    Use the following format for the blog:

    Title: <title of the blog>
    Date: <current date>
    Blog: <the text of the blog>
    HTML version: <HTML of the title and blog text>
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))

blog_text = create_blog_post(topic, length)

print(blog_text)

# %%
def create_blog_post(topic, length=300, tone=1):
    
    if tone == 1:
        tone_description = 'funny'
    elif tone == 2:
        tone_description = 'serious'
    else:
        tone_description = 'neutral'

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    The tone is {tone_description}
    Create an interesting title for the blog.  Also, translate the title and blog tet
    into HTML.
    
    Use the following format for the blog:

    Title: <title of the blog>
    Date: <current date>
    Blog: <the text of the blog>
    HTML version: <HTML of the title and blog text>
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))
tone = int(input("Enter the tone: 1=funny, 2=serious, 3=neutral"))

blog_text = create_blog_post(topic, length, tone)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 200
# Enter the tone: 1=funny, 2=serious, 3=neutral1
# Title: RISE OF THE MACHINES: A JOKE ABOUT GENERATIVE AI
#
# Date: July 23, 2021
#
# Blog:
#
# Generative AI – the magic that happens when machines begin to create art, music, and even literature. Not only are they already better at math and problem-solving than humans, but now they're coming for our jobs as painters and writers too.
#
# They can now autonomously create paintings, compose tunes, and even generate fake news articles. To think, we used to fear artificial intelligence would only aim for world domination, but now it appears that its priorities have shifted towards usurping the entire creative industry.
#
# They say AI will always need humans to supervise and evaluate but who are they kidding? We all know that once these machines start doing better poetry than us, it's just a matter of time before they kick us to the curb and take over as world-renowned poets.
#
# To top it off, because AI is programmed to be unbiased and objective, there's a chance replace all the American Idol judges with a simple algorithm. The future will never be American Idol again, but at least we'll have one less Simon Cowell in the world.
#
# In all honesty, though – no one knows what the future holds. Maybe someday, they'll even create an AI stand-up comedian that's way funnier than this blog.
#
# HTML version:
#
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Rise of the Machines: A Joke About Generative AI</title>
# </head>
# <body>
# 	<h1>Rise of the Machines: A Joke About Generative AI</h1>
# 	<p>Generative AI – the magic that happens when machines begin to create art, music, and even literature. Not only are they already better at math and problem-solving than humans, but now they're coming for our jobs as painters and writers too.</p>
# 	<p>They can now autonomously create paintings, compose tunes, and even generate fake news articles. To think, we used to fear artificial intelligence would only aim for world domination, but now it appears that its priorities have shifted towards usurping the entire creative industry.</p>
# 	<p>They say AI will always need humans to supervise and evaluate but who are they kidding? We all know that once these machines start doing better poetry than us, it's just a matter of time before they kick us to the curb and take over as world-renowned poets.</p>
# 	<p>To top it off, because AI is programmed to be unbiased and objective, there's a chance replace all the American Idol judges with a simple algorithm. The future will never be American Idol again, but at least we'll have one less Simon Cowell in the world.</p>
# 	<p>In all honesty, though – no one knows what the future holds. Maybe someday, they'll even create an AI stand-up comedian that's way funnier than this blog. </p>
# </body>
# </html>

# %%
def create_blog_post(topic, length=300, tone=1):
    
    if tone == 1:
        tone_description = 'funny'
    elif tone == 2:
        tone_description = 'serious'
    else:
        tone_description = 'neutral'

    prompt = f''' 
    
    Write a blog about {topic}. Limit it to no more than {length} words.
    The tone is {tone_description}. Write in the active voice. 
    Write at a 5th grade level.
    Create an interesting title for the blog.  
    Create section headings.
    Write a one or two sentence summary of the blog post.
    
    
    Also, translate the title and blog tet
    into HTML.
    
    Use the following format for the blog:

    Title: <title of the blog>
    Date: <current date>
    Summary: <one or two sentence summary of the blog post>
    Blog: <the text of the blog>
    HTML version: <HTML of the title and blog text>
    
    ''' 

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert blog writer",
            "role": "user", "content": prompt},
        ],
        # max_tokens=length
    )
    
    return response.choices[0]['message']['content']

print("Welcome to the Blog Creator!\n")

topic = input("Enter a topic for the blog: ")
length = int(input("Enter the maximum length: "))
tone = int(input("Enter the tone: 1=funny, 2=serious, 3=neutral"))

blog_text = create_blog_post(topic, length, tone)

print(blog_text)
# Out:
# Welcome to the Blog Creator!
#
# Enter a topic for the blog: generative ai
# Enter the maximum length: 400
# Enter the tone: 1=funny, 2=serious, 3=neutral1
# Title: What's the Deal with Generative AI?
#     Date: September 29, 2021
#     Blog:
#
#     Alright, folks. Today we're talking about generative AI. You might be asking yourself, "What the heck is that?" Well, let me tell you. Generative AI is when machines use algorithms to create and generate something new, like music or art. Sounds fancy, right? But what's the big deal?
#
#     The Science Behind It
#
#     Basically, generative AI uses deep learning neural networks to process data and create something brand spanking new. It's like the machines are trying to be the Picasso of AI. And just like how we learn, the more data the machines have, the better they can create. It's all about practice, practice, practice.
#
#     What Can It Do?
#
#     So, what can generative AI do? The sky's the limit, really. From creating unique and original music to designing clothes, generative AI is versatile. But it's not just about creating new things. It can also be used to improve existing things. Take Google's DeepMind, for example. They used generative AI to create a new way of predicting the shape of protein molecules. This could potentially revolutionize how we approach medicine and drug discovery.
#
#     The Good, the Bad, and the Ugly
#
#     Now, let's talk about the pros and cons of generative AI. On the one hand, it has the potential to revolutionize the way we create and improve things like music, art, and medicine. On the other hand, some worry that it could put jobs at risk, like musicians or graphic designers. And of course, there's always the worry of machines becoming too smart and taking over the world. But for now, that's just a sci-fi movie plot.
#
#     The Bottom Line
#
#     Generative AI is exciting and has the potential to do some pretty amazing things. But like all things, it has its pros and cons. So, let's just remember to use our powers for good and hope the machines don't become too smart for their own good.
#
#     Summary: Generative AI uses algorithms to create something new like music or art. It can improve existing things, potentially revolutionize medicine, and even put jobs at risk. Let's just hope the machines don't take over the world.
#
#     HTML version:
#
#     <html>
#     <head>
#     <title>What's the Deal with Generative AI?</title>
#     </head>
#     <body>
#     <h1>What's the Deal with Generative AI?</h1>
#     <h3>The Science Behind It</h3>
#     <p>Basically, generative AI uses deep learning neural networks to process data and create something brand spanking new. It's like the machines are trying to be the Picasso of AI. And just like how we learn, the more data the machines have, the better they can create. It's all about practice, practice, practice.</p>
#     <h3>What Can It Do?</h3>
#     <p>So, what can generative AI do? The sky's the limit, really. From creating unique and original music to designing clothes, generative AI is versatile. But it's not just about creating new things. It can also be used to improve existing things. Take Google's DeepMind, for example. They used generative AI to create a new way of predicting the shape of protein molecules. This could potentially revolutionize how we approach medicine and drug discovery.</p>
#     <h3>The Good, the Bad, and the Ugly</h3>
#     <p>Now, let's talk about the pros and cons of generative AI. On the one hand, it has the potential to revolutionize the way we create and improve things like music, art, and medicine. On the other hand, some worry that it could put jobs at risk, like musicians or graphic designers. And of course, there's always the worry of machines becoming too smart and taking over the world. But for now, that's just a sci-fi movie plot.</p>
#     <h3>The Bottom Line</h3>
#     <p>Generative AI is exciting and has the potential to do some pretty amazing things. But like all things, it has its pros and cons. So, let's just remember to use our powers for good and hope the machines don't become too smart for their own good.</p>
#     </body>
#     </html>
